# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("../../data/raw/matches.csv")
data.head(1)
# Out:
#        id   season       city        date match_type player_of_match  \
# 0  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
#
#                    venue                        team1                  team2  \
# 0  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
#
#    result_margin  target_runs  target_overs super_over method    umpire1  \
# 0          140.0        223.0          20.0          N    NaN  Asad Rauf
#
#        umpire2
# 0  RE Koertzen

# %%
toss_data = data.iloc[:,[1,2,3,6,7,8,9,10,11]]
toss_data.head(1)
# Out:
#     season       city        date                  venue  \
# 0  2007/08  Bangalore  2008-04-18  M Chinnaswamy Stadium
#
#                          team1                  team2  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner toss_decision                 winner
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders

# %% [markdown]
# **to do**
# team -> toss win percentage
# toss- > match
# match winning percent -> after toss win
# team decision->after toss win
# toss win ->fwild -> percentage
#          ->bat ->percentage
# venue -> toss who wins
# vennue -> bat or bowl when toss win
# year wise -> decision stats

# %%
noofmatches = data["team1"].value_counts() + data["team2"].value_counts()
noofmatches = noofmatches.reset_index()
noofmatches
# Out:
#                           index  count
# 0           Chennai Super Kings    238
# 1               Deccan Chargers     75
# 2                Delhi Capitals     91
# 3              Delhi Daredevils    161
# 4                 Gujarat Lions     30
# 5                Gujarat Titans     45
# 6               Kings XI Punjab    190
# 7          Kochi Tuskers Kerala     14
# 8         Kolkata Knight Riders    251
# 9          Lucknow Super Giants     44
# 10               Mumbai Indians    261
# 11                Pune Warriors     46
# 12                 Punjab Kings     56
# 13             Rajasthan Royals    221
# 14       Rising Pune Supergiant     16
# 15      Rising Pune Supergiants     14
# 16  Royal Challengers Bangalore    240
# 17  Royal Challengers Bengaluru     15
# 18          Sunrisers Hyderabad    182

# %%
noofmatches.iloc[15,1]+=noofmatches.iloc[14,1]
noofmatches.iloc[16,1]+=noofmatches.iloc[17,1]
noofmatches
# Out:
#                           index  count
# 0           Chennai Super Kings    238
# 1               Deccan Chargers     75
# 2                Delhi Capitals     91
# 3              Delhi Daredevils    161
# 4                 Gujarat Lions     30
# 5                Gujarat Titans     45
# 6               Kings XI Punjab    190
# 7          Kochi Tuskers Kerala     14
# 8         Kolkata Knight Riders    251
# 9          Lucknow Super Giants     44
# 10               Mumbai Indians    261
# 11                Pune Warriors     46
# 12                 Punjab Kings     56
# 13             Rajasthan Royals    221
# 14       Rising Pune Supergiant     16
# 15      Rising Pune Supergiants     30
# 16  Royal Challengers Bangalore    255
# 17  Royal Challengers Bengaluru     15
# 18          Sunrisers Hyderabad    182

# %%
noofmatches.drop(labels="Rising Pune Supergiant",inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 noofmatches.drop(labels="Rising Pune Supergiant",inplace= True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
# ...

# %% [markdown]
# **Team Toss Percentage**
